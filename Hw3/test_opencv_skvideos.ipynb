# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))
# Out:
# Using TensorFlow backend.

# %%
skvideo.setFFmpegPath('D:/Tsou/Anaconda/envs/opencv/lib/site-packages/ffmpeg/')
skvideo.io.vwrite('test.mp4',  np.random.uniform(0,255,size=(100,100,100)))
HTML(display_videos('test.mp4'))
# Out:
# D:\Tsou\Anaconda\envs\opencv\lib\site-packages\skvideo\__init__.py:306: UserWarning: ffmpeg/ffprobe not found in path: D:/Tsou/Anaconda/envs/opencv/lib/site-packages/ffmpeg/
#   warnings.warn("ffmpeg/ffprobe not found in path: " + str(path), UserWarning)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
